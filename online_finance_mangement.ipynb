# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
from datetime import datetime

mydb = mysql.connector.connect(
    host="localhost",
    user="root", 
    database="finance_db"
)

cursor = mydb.cursor()


def add_income(amount, category, description=""):
    query = "INSERT INTO transactions (type, amount, category, date, description) VALUES (%s, %s, %s, %s, %s)"
    values = ("income", amount, category, datetime.now().date(), description)
    cursor.execute(query, values)
    mydb.commit()
    print("Income added successfully!")


def add_expense(amount, category, description=""):
    query = "INSERT INTO transactions (type, amount, category, date, description) VALUES (%s, %s, %s, %s, %s)"
    values = ("expense", amount, category, datetime.now().date(), description)
    cursor.execute(query, values)
    mydb.commit()
    print("Expense added successfully!")

def generate_report():
    cursor.execute("SELECT type, SUM(amount) FROM transactions GROUP BY type")
    results = cursor.fetchall()

    total_income = 0
    total_expense = 0

    for row in results:
        if row[0] == "income":
            total_income = row[1]
        elif row[0] == "expense":
            total_expense = row[1]

    balance = total_income - total_expense

    print(f"Total Income: {total_income}")
    print(f"Total Expenses: {total_expense}")
    print(f"Balance: {balance}")

# Main menu
def main():
    while True:
        print("\nPersonal Finance Management System")
        print("1. Add Income")
        print("2. Add Expense")
        print("3. Generate Report")
        print("4. Exit")
        choice = input("Enter your choice: ")

        if choice == "1":
            amount = float(input("Enter amount: "))
            category = input("Enter category: ")
            description = input("Enter description (optional): ")
            add_income(amount, category, description)
        elif choice == "2":
            amount = float(input("Enter amount: "))
            category = input("Enter category: ")
            description = input("Enter description (optional): ")
            add_expense(amount, category, description)
        elif choice == "3":
            generate_report()
        elif choice == "4":
            print("Goodbye!")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()

cursor.close()
mydb.close()
# Out:
# Personal Finance Management System
# 1. Add Income
# 2. Add Expense
# 3. Generate Report
# 4. Exit
# Enter your choice: 1
# Enter amount: 34555
# Enter category: job
# Enter description (optional): fkg
# Income added successfully!
#
# Personal Finance Management System
# 1. Add Income
# 2. Add Expense
# 3. Generate Report
# 4. Exit
# Enter your choice: 2
# Enter amount: 2478
# Enter category: sjhopp
# Enter description (optional): dkf
# Expense added successfully!
#
# Personal Finance Management System
# 1. Add Income
# 2. Add Expense
# 3. Generate Report
# 4. Exit
# Enter your choice: 3
# Total Income: 34555.00
# Total Expenses: 2478.00
# Balance: 32077.00
#
# Personal Finance Management System
# 1. Add Income
# 2. Add Expense
# 3. Generate Report
# 4. Exit
